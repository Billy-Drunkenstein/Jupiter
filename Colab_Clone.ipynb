# %% [markdown]
# <a href="https://colab.research.google.com/github/Billy-Drunkenstein/Jupiter/blob/main/Colab_Clone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Billy-Drunkenstein/Jupiter.git
# Out:
# Cloning into 'Jupiter'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 16 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 5.37 KiB | 916.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/Jupiter
# !git pull
# Out:
# /content/Jupiter
# Already up to date.
